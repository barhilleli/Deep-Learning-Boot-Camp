# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/barhilleli/Deep-Learning-Boot-Camp/blob/master/keras_cartpole_colab.ipynb)
# (need to open in new a tab)

# %%
import gym
import random
import os
import numpy as np
from collections      import deque
from keras.models     import Sequential
from keras.layers     import Dense
from keras.optimizers import Adam

class Agent():
    def __init__(self, state_size, action_size):
        self.weight_backup      = "cartpole_weight.h5"
        self.state_size         = state_size
        self.action_size        = action_size
        self.memory             = deque(maxlen=2000)
        self.learning_rate      = 0.001
        self.gamma              = 0.95
        self.exploration_rate   = 1.0
        self.exploration_min    = 0.01
        self.exploration_decay  = 0.995
        self.brain              = self._build_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))

        if os.path.isfile(self.weight_backup):
            model.load_weights(self.weight_backup)
            self.exploration_rate = self.exploration_min
        return model

    def save_model(self):
            self.brain.save(self.weight_backup)

    def act(self, state):
        if np.random.rand() <= self.exploration_rate:
            return random.randrange(self.action_size)
        act_values = self.brain.predict(state)
        return np.argmax(act_values[0])

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self, sample_batch_size):
        if len(self.memory) < sample_batch_size:
            return
        sample_batch = random.sample(self.memory, sample_batch_size)
        for state, action, reward, next_state, done in sample_batch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.brain.predict(next_state)[0])
            target_f = self.brain.predict(state)
            target_f[0][action] = target
            self.brain.fit(state, target_f, epochs=1, verbose=0)
        if self.exploration_rate > self.exploration_min:
            self.exploration_rate *= self.exploration_decay

            
            
class CartPole:
    def __init__(self):
        self.sample_batch_size = 32
        self.episodes          = 10000
        self.env               = gym.make('CartPole-v1')

        self.state_size        = self.env.observation_space.shape[0]
        self.action_size       = self.env.action_space.n
        self.agent             = Agent(self.state_size, self.action_size)
        self.episode_duration  = []


    def run(self):
        try:
            for index_episode in range(self.episodes):
                state = self.env.reset()
                state = np.reshape(state, [1, self.state_size])

                done = False
                index = 0
                while not done:
                    self.env.render()

                    action = self.agent.act(state)

                    next_state, reward, done, _ = self.env.step(action)
                    next_state = np.reshape(next_state, [1, self.state_size])
                    self.agent.remember(state, action, reward, next_state, done)
                    state = next_state
                    index += 1
                print("Episode {}# Score: {}".format(index_episode, index + 1))
                self.episode_duration.append(index+1)
                self.agent.replay(self.sample_batch_size)
        finally:
            self.agent.save_model()

            
    def plot_durations(self):
        plt.figure(2)
        plt.clf()
        plt.title('Training...')
        plt.xlabel('Episode')
        plt.ylabel('Duration')
        plt.plot(self.episode_duration)
        # Take 100 episode averages and plot them too
        if len(self.episode_duration) >= 100:
            means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
            means = torch.cat((torch.zeros(99), means))
            plt.plot(means.numpy())

    #     plt.pause(0.001)  # pause a bit so that plots are updated - don't need this!!
        if is_ipython:
            display.clear_output(wait=True)
            display.display(plt.gcf())

            
if __name__ == "__main__":
    cartpole = CartPole()
    cartpole.run()
# Out:
# /Users/barh/.local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/barh/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1349: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Episode 0# Score: 13
# Episode 1# Score: 26
# Episode 2# Score: 22
# Episode 3# Score: 34
# Episode 4# Score: 22
# Episode 5# Score: 38
# Episode 6# Score: 24
# Episode 7# Score: 15
# Episode 8# Score: 34
# Episode 9# Score: 34
# Episode 10# Score: 25
# Episode 11# Score: 28
# Episode 12# Score: 18
# Episode 13# Score: 25
# Episode 14# Score: 14
# Episode 15# Score: 24
# Episode 16# Score: 20
# Episode 17# Score: 26
# Episode 18# Score: 24
# Episode 19# Score: 14
# Episode 20# Score: 20
# Episode 21# Score: 20
# Episode 22# Score: 22
# Episode 23# Score: 19
# Episode 24# Score: 13
# Episode 25# Score: 15
# Episode 26# Score: 13
# Episode 27# Score: 16
# Episode 28# Score: 14
# Episode 29# Score: 11
# Episode 30# Score: 15
# Episode 31# Score: 41
# Episode 32# Score: 16
# Episode 33# Score: 15
# Episode 34# Score: 36
# Episode 35# Score: 15
# Episode 36# Score: 18
# Episode 37# Score: 12
# Episode 38# Score: 15
# Episode 39# Score: 19
# Episode 40# Score: 13
# Episode 41# Score: 27
# Episode 42# Score: 17
# Episode 43# Score: 15
# Episode 44# Score: 15
# Episode 45# Score: 27
# Episode 46# Score: 52
# Episode 47# Score: 19
# Episode 48# Score: 16
# Episode 49# Score: 29
# Episode 50# Score: 15
# Episode 51# Score: 14
# Episode 52# Score: 9
# Episode 53# Score: 16
# Episode 54# Score: 12
# Episode 55# Score: 11
# Episode 56# Score: 20
# Episode 57# Score: 26
# Episode 58# Score: 40
# Episode 59# Score: 12
# Episode 60# Score: 12
# Episode 61# Score: 16
# Episode 62# Score: 18
# Episode 63# Score: 15
# Episode 64# Score: 16
# Episode 65# Score: 18
# Episode 66# Score: 17
# Episode 67# Score: 53
# Episode 68# Score: 17
# Episode 69# Score: 11
# Episode 70# Score: 15
# Episode 71# Score: 25
# Episode 72# Score: 12
# Episode 73# Score: 17
# Episode 74# Score: 13
# Episode 75# Score: 15
# Episode 76# Score: 12
# Episode 77# Score: 15
# Episode 78# Score: 12
# Episode 79# Score: 16
# Episode 80# Score: 22
# Episode 81# Score: 16
# Episode 82# Score: 9
# Episode 83# Score: 15
# Episode 84# Score: 15
# Episode 85# Score: 17
# Episode 86# Score: 16
# Episode 87# Score: 13
# Episode 88# Score: 17
# Episode 89# Score: 18
# Episode 90# Score: 17
# Episode 91# Score: 11
# Episode 92# Score: 13
# Episode 93# Score: 39
# Episode 94# Score: 11
# Episode 95# Score: 13
# Episode 96# Score: 39
# Episode 97# Score: 16
# Episode 98# Score: 12
# Episode 99# Score: 21
# Episode 100# Score: 15
# Episode 101# Score: 11
# Episode 102# Score: 18
# Episode 103# Score: 12
# Episode 104# Score: 14
# Episode 105# Score: 14
# Episode 106# Score: 15
# Episode 107# Score: 13
# Episode 108# Score: 20
# Episode 109# Score: 14
# Episode 110# Score: 14
# Episode 111# Score: 19
# Episode 112# Score: 11
# Episode 113# Score: 27
# Episode 114# Score: 16
# Episode 115# Score: 10
# Episode 116# Score: 10
# Episode 117# Score: 13
# Episode 118# Score: 20
# Episode 119# Score: 27
# Episode 120# Score: 11
# Episode 121# Score: 14
# Episode 122# Score: 12
# Episode 123# Score: 10
# Episode 124# Score: 18
# Episode 125# Score: 12
# Episode 126# Score: 35
# Episode 127# Score: 26
# Episode 128# Score: 11
# Episode 129# Score: 11
# Episode 130# Score: 19
# Episode 131# Score: 12
# Episode 132# Score: 11
# Episode 133# Score: 20
# Episode 134# Score: 14
# Episode 135# Score: 13
# Episode 136# Score: 14
# Episode 137# Score: 23
# Episode 138# Score: 10
# Episode 139# Score: 17
# Episode 140# Score: 13
# Episode 141# Score: 12
# Episode 142# Score: 17
# Episode 143# Score: 27
# Episode 144# Score: 12
# Episode 145# Score: 10
# Episode 146# Score: 20
# Episode 147# Score: 16
# Episode 148# Score: 10
# Episode 149# Score: 12
# Episode 150# Score: 11
# Episode 151# Score: 14
# Episode 152# Score: 14
# Episode 153# Score: 12
# Episode 154# Score: 14
# Episode 155# Score: 17
# Episode 156# Score: 16
# Episode 157# Score: 12
# Episode 158# Score: 18
# Episode 159# Score: 11
# Episode 160# Score: 12
# Episode 161# Score: 11
# Episode 162# Score: 18
# Episode 163# Score: 12
# Episode 164# Score: 13
# Episode 165# Score: 17
# Episode 166# Score: 13
# Episode 167# Score: 39
# Episode 168# Score: 15
# Episode 169# Score: 14
# Episode 170# Score: 33
# Episode 171# Score: 41
# Episode 172# Score: 34
# Episode 173# Score: 37
# Episode 174# Score: 65
# Episode 175# Score: 49
# Episode 176# Score: 23
# Episode 177# Score: 78
# Episode 178# Score: 23
# Episode 179# Score: 30
# Episode 180# Score: 81
# Episode 181# Score: 28
# Episode 182# Score: 22
# Episode 183# Score: 28
# Episode 184# Score: 25
# Episode 185# Score: 24
# Episode 186# Score: 24
# Episode 187# Score: 34
# Episode 188# Score: 33
# Episode 189# Score: 16
# Episode 190# Score: 22
# Episode 191# Score: 21
# Episode 192# Score: 17
# Episode 193# Score: 20
# Episode 194# Score: 23
# Episode 195# Score: 158
# Episode 196# Score: 17
# Episode 197# Score: 38
# Episode 198# Score: 28
# Episode 199# Score: 19
# Episode 200# Score: 42
# Episode 201# Score: 49
# Episode 202# Score: 38
# Episode 203# Score: 29
# Episode 204# Score: 28
# Episode 205# Score: 29
# Episode 206# Score: 31
# Episode 207# Score: 45
# Episode 208# Score: 47
# Episode 209# Score: 18
# Episode 210# Score: 21
# Episode 211# Score: 33
# Episode 212# Score: 47
# Episode 213# Score: 30
# Episode 214# Score: 55
# Episode 215# Score: 39
# Episode 216# Score: 53
# Episode 217# Score: 19
# Episode 218# Score: 28
# Episode 219# Score: 37
# Episode 220# Score: 32
# Episode 221# Score: 31
# Episode 222# Score: 47
# Episode 223# Score: 44
# Episode 224# Score: 13
# Episode 225# Score: 30
# Episode 226# Score: 133
# Episode 227# Score: 53
# Episode 228# Score: 41
# Episode 229# Score: 114
# Episode 230# Score: 55
# Episode 231# Score: 15
# Episode 232# Score: 19
# Episode 233# Score: 42
# Episode 234# Score: 37
# Episode 235# Score: 22
# Episode 236# Score: 18
# Episode 237# Score: 27
# Episode 238# Score: 18
# Episode 239# Score: 128
# Episode 240# Score: 48
# Episode 241# Score: 41
# Episode 242# Score: 45
# Episode 243# Score: 43
# Episode 244# Score: 29
# Episode 245# Score: 58
# Episode 246# Score: 35
